# %% [markdown]
# # Connection Establishment & Request

# %%
import urllib.request
req = urllib.request.urlopen("https://www.google.com")
print(req.read())
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="JFKExRq2yKLuJhYEXoTE7Q==">(function(){window.google={kEI:\'zxVoW47XMMqWtQWAmoL4Aw\',kEXPI:\'0,1352961,786,57,1370,283,305,1298,334,8,495,877,483,147,5,294,387,50,325,425,34,484,2338654,254,173,32,329294,1294,12383,2349,2506,32692,15247,867,6692,5471,5281,621,479,3335,2,2,4609,2192,365,552,664,2102,113,2201,3191,224,501,3,1708,136,130,1269,3838,575,1119,2,579,727,310,3,299,1819,59,2,2,2,190,1107,1705,7,1376,505,730,403,1693,664,632,6,274,26,1269,774,1232,883,139,277,2,694,148,282,1701,437,349,455,395,525,621,5,2,2,743,1021,264,269,117,2,75,3,741,590,301,425,189,283,509,1587,296,1344,9,60,1050,334,55,75,1110,78,156,386,10,1001,81,7,3,25,465,439,179,29,707,282,406,451,7,62,569,917,299,93,514,162,439,97,
# ...

# %% [markdown]
# # URL Encoding

# %%
import urllib.request
import urllib.parse
url = 'https://google.com/search'
values = {'q':'python programing tutorial'}

data = urllib.parse.urlencode(values)
print(data)
print(100 * '*')

data = data.encode('utf-8')
print(data)
print(100 * '*')

req = urllib.request.Request(url,data)
resp = urllib.request.urlopen(req)
print(resp.read())
# Out:
# q=python+programing+tutorial
# ****************************************************************************************************
# b'q=python+programing+tutorial'
# ****************************************************************************************************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-8f03f37a66ec> in <module>()
#      13
#      14 req = urllib.request.Request(url,data)
# ---> 15 resp = urllib.request.urlopen(req)
#      16 print(resp.read())
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %%
import urllib.request
import urllib.parse

values = {'q':'python programing tutorial'}

data = urllib.parse.urlencode(values)
print(data)
print(100 * '*')
url = 'https://google.com/search?'+ data


req = urllib.request.Request(url)
resp = urllib.request.urlopen(req)
print(resp.read())
# Out:
# q=python+programing+tutorial
# ****************************************************************************************************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-d8b0b908e1f5> in <module>()
#      11
#      12 req = urllib.request.Request(url)
# ---> 13 resp = urllib.request.urlopen(req)
#      14 print(resp.read())
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# ...

# %%
import urllib.request
import urllib.parse

values = {'q':'python programing tutorial'}

data = urllib.parse.urlencode(values)
print(data)
print(100 * '*')
url = 'https://google.com/search?'+ data

headers = {}
headers['User-Agent'] = "Chrome"

req = urllib.request.Request(url,headers = headers)
resp = urllib.request.urlopen(req)
print(resp.read())
# Out:
# q=python+programing+tutorial
# ****************************************************************************************************
# ...

# %% [markdown]
# # XML Parsing

# %%
from bs4 import BeautifulSoup
import urllib.request

req = urllib.request.urlopen('https://www.nationaljournal.com/login')
xml = BeautifulSoup(req,'xml')

for item in xml.findAll('link'):
    print(item.text)
